# %% [markdown]
# <a href="https://colab.research.google.com/github/RAJ-15012006/delta/blob/main/Datascience7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Create a Time Series Model to predict the future air passenger traffic

# %%
# importing libraries
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# loadind the data
data = pd.read_csv('/content/AirPassengers.csv')

# %%
data
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
data.shape
 # 144 rows, 2 cols
# Out:
# (144, 2)

# %%
data.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
data.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
data.dtypes
# Out:
# Month          object
# #Passengers     int64
# dtype: object

# %%
data.info() #info about datatype and null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
# Month is actually given as string/object here. It must be in date-time format

# %%
# parse_dates: parsing the date (Converts the string representation of a date to Date object)
# index_col: using date column as index

data=pd.read_csv('/content/AirPassengers.csv',parse_dates=[0],index_col='Month') # string into date object and month is in 0

# %%
data
# predict no. of passengers travelled
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
data.rename(columns={'#Passengers': 'Passengers'}, inplace = True)

# %%
data.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
